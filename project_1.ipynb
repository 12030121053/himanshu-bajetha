# %%
import numpy as np
import pandas as pd

# %%
himanshu=pd.read_csv("G:\\basic python\\Data Science with Python Two\\311_Service_Requests_from_2010_to_Present.csv")
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_7512\1296161484.py:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   himanshu=pd.read_csv("G:\\basic python\\Data Science with Python Two\\311_Service_Requests_from_2010_to_Present.csv")

# %%
himanshu.head()
# Out:
#    Unique Key      Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 23:59  1/1/2016 0:55   NYPD
# 1    32309934  12/31/2015 23:59  1/1/2016 1:26   NYPD
# 2    32309159  12/31/2015 23:59  1/1/2016 4:51   NYPD
# 3    32305098  12/31/2015 23:57  1/1/2016 7:43   NYPD
# 4    32306529  12/31/2015 23:56  1/1/2016 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# 2                     No Access  Street/Sidewalk       10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk       10461.0
# 4              Blocked Sidewalk  Street/Sidewalk       11373.0
#
#         Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0    71 VERMILYEA AVENUE  ...                 NaN                      NaN
# 1        27-07 23 AVENUE  ...                 NaN                      NaN
# 2  2897 VALENTINE AVENUE  ...                 NaN                      NaN
# 3    2940 BAISLEY AVENUE  ...                 NaN                      NaN
# 4          87-14 57 ROAD  ...                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 0       NaN                    NaN             NaN             NaN
# 1       NaN                    NaN             NaN             NaN
# 2       NaN                    NaN             NaN             NaN
# 3       NaN                    NaN             NaN             NaN
# 4       NaN                    NaN             NaN             NaN
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                 NaN  40.865682 -73.923501
# 1                 NaN  40.775945 -73.915094
# 2                 NaN  40.870325 -73.888525
# 3                 NaN  40.835994 -73.828379
# 4                 NaN  40.733060 -73.874170
#
#                                    Location
# 0   (40.86568153633767, -73.92350095571744)
# 1  (40.775945312321085, -73.91509393898605)
# 2  (40.870324522111424, -73.88852464418646)
# 3   (40.83599404683083, -73.82837939584206)
# 4  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
himanshu.shape
# Out:
# (300698, 53)

# %%
himanshu.dropna(how='all',axis=0)
# Out:
#         Unique Key      Created Date     Closed Date Agency  \
# 0         32310363  12/31/2015 23:59   1/1/2016 0:55   NYPD
# 1         32309934  12/31/2015 23:59   1/1/2016 1:26   NYPD
# 2         32309159  12/31/2015 23:59   1/1/2016 4:51   NYPD
# 3         32305098  12/31/2015 23:57   1/1/2016 7:43   NYPD
# 4         32306529  12/31/2015 23:56   1/1/2016 3:24   NYPD
# ...            ...               ...             ...    ...
# 300693    30281872    3/29/2015 0:33             NaN   NYPD
# 300694    30281230    3/29/2015 0:33  3/29/2015 2:33   NYPD
# 300695    30283424    3/29/2015 0:33  3/29/2015 3:40   NYPD
# 300696    30280004    3/29/2015 0:33  3/29/2015 4:38   NYPD
# 300697    30281825    3/29/2015 0:33  3/29/2015 4:41   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# 1       New York City Police Department         Blocked Driveway
# 2       New York City Police Department         Blocked Driveway
# 3       New York City Police Department          Illegal Parking
# 4       New York City Police Department          Illegal Parking
# ...                                 ...                      ...
# 300693  New York City Police Department       Noise - Commercial
# 300694  New York City Police Department         Blocked Driveway
# 300695  New York City Police Department       Noise - Commercial
# 300696  New York City Police Department       Noise - Commercial
# 300697  New York City Police Department       Noise - Commercial
#
#                           Descriptor        Location Type  Incident Zip  \
# 0                   Loud Music/Party      Street/Sidewalk       10034.0
# 1                          No Access      Street/Sidewalk       11105.0
# 2                          No Access      Street/Sidewalk       10458.0
# 3       Commercial Overnight Parking      Street/Sidewalk       10461.0
# 4                   Blocked Sidewalk      Street/Sidewalk       11373.0
# ...                              ...                  ...           ...
# 300693              Loud Music/Party  Club/Bar/Restaurant           NaN
# 300694                Partial Access      Street/Sidewalk       11418.0
# 300695              Loud Music/Party  Club/Bar/Restaurant       11206.0
# 300696              Loud Music/Party  Club/Bar/Restaurant       10461.0
# 300697              Loud Music/Party     Store/Commercial       10036.0
#
#                 Incident Address  ... Bridge Highway Name  \
# 0            71 VERMILYEA AVENUE  ...                 NaN
# 1                27-07 23 AVENUE  ...                 NaN
# 2          2897 VALENTINE AVENUE  ...                 NaN
# 3            2940 BAISLEY AVENUE  ...                 NaN
# 4                  87-14 57 ROAD  ...                 NaN
# ...                          ...  ...                 ...
# 300693           CRESCENT AVENUE  ...                 NaN
# 300694          100-17 87 AVENUE  ...                 NaN
# 300695         162 THROOP AVENUE  ...                 NaN
# 300696  3151 EAST TREMONT AVENUE  ...                 NaN
# 300697        251 WEST 48 STREET  ...                 NaN
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 0                           NaN       NaN                    NaN
# 1                           NaN       NaN                    NaN
# 2                           NaN       NaN                    NaN
# 3                           NaN       NaN                    NaN
# 4                           NaN       NaN                    NaN
# ...                         ...       ...                    ...
# 300693                      NaN       NaN                    NaN
# 300694                      NaN       NaN                    NaN
# 300695                      NaN       NaN                    NaN
# 300696                      NaN       NaN                    NaN
# 300697                      NaN       NaN                    NaN
#
#        Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  \
# 0                  NaN             NaN                 NaN  40.865682
# 1                  NaN             NaN                 NaN  40.775945
# 2                  NaN             NaN                 NaN  40.870325
# 3                  NaN             NaN                 NaN  40.835994
# 4                  NaN             NaN                 NaN  40.733060
# ...                ...             ...                 ...        ...
# 300693             NaN             NaN                 NaN        NaN
# 300694             NaN             NaN                 NaN  40.694077
# 300695             NaN             NaN                 NaN  40.699590
# 300696             NaN             NaN                 NaN  40.837708
# 300697             NaN             NaN                 NaN  40.760583
#
#         Longitude                                  Location
# 0      -73.923501   (40.86568153633767, -73.92350095571744)
# 1      -73.915094  (40.775945312321085, -73.91509393898605)
# 2      -73.888525  (40.870324522111424, -73.88852464418646)
# 3      -73.828379   (40.83599404683083, -73.82837939584206)
# 4      -73.874170  (40.733059618956815, -73.87416975810375)
# ...           ...                                       ...
# 300693        NaN                                       NaN
# 300694 -73.846087    (40.69407728322387, -73.8460866160573)
# 300695 -73.944234   (40.69959035300927, -73.94423377144169)
# 300696 -73.834587    (40.8377075854206, -73.83458731019586)
# 300697 -73.985922   (40.76058322950115, -73.98592204392392)
#
# [300698 rows x 53 columns]

# %%
himanshu.head()
# Out:
#    Unique Key      Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 23:59  1/1/2016 0:55   NYPD
# 1    32309934  12/31/2015 23:59  1/1/2016 1:26   NYPD
# 2    32309159  12/31/2015 23:59  1/1/2016 4:51   NYPD
# 3    32305098  12/31/2015 23:57  1/1/2016 7:43   NYPD
# 4    32306529  12/31/2015 23:56  1/1/2016 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# 2                     No Access  Street/Sidewalk       10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk       10461.0
# 4              Blocked Sidewalk  Street/Sidewalk       11373.0
#
#         Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0    71 VERMILYEA AVENUE  ...                 NaN                      NaN
# 1        27-07 23 AVENUE  ...                 NaN                      NaN
# 2  2897 VALENTINE AVENUE  ...                 NaN                      NaN
# 3    2940 BAISLEY AVENUE  ...                 NaN                      NaN
# 4          87-14 57 ROAD  ...                 NaN                      NaN
#
#   Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 0       NaN                    NaN             NaN             NaN
# 1       NaN                    NaN             NaN             NaN
# 2       NaN                    NaN             NaN             NaN
# 3       NaN                    NaN             NaN             NaN
# 4       NaN                    NaN             NaN             NaN
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                 NaN  40.865682 -73.923501
# 1                 NaN  40.775945 -73.915094
# 2                 NaN  40.870325 -73.888525
# 3                 NaN  40.835994 -73.828379
# 4                 NaN  40.733060 -73.874170
#
#                                    Location
# 0   (40.86568153633767, -73.92350095571744)
# 1  (40.775945312321085, -73.91509393898605)
# 2  (40.870324522111424, -73.88852464418646)
# 3   (40.83599404683083, -73.82837939584206)
# 4  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
himanshu.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# Community Board                        0
# Borough                                0
# X Coordinate (State Plane)          3540
# Y Coordinate (State Plane)          3540
# Park Facility Name                     0
# Park Borough                           0
# School Name                            0
# School Number                          0
# School Region                          1
# School Code                            1
# School Phone Number                    0
# School Address                         0
# School City                            0
# School State                           0
# School Zip                             1
# School Not Found                       0
# School or Citywide Complaint      300698
# Vehicle Type                      300698
# Taxi Company Borough              300698
# Taxi Pick Up Location             300698
# Bridge Highway Name               300455
# Bridge Highway Direction          300455
# Road Ramp                         300485
# Bridge Highway Segment            300485
# Garage Lot Name                   300698
# Ferry Direction                   300697
# Ferry Terminal Name               300696
# Latitude                            3540
# Longitude                           3540
# Location                            3540
# dtype: int64

# %%
himanshu.shape
# Out:
# (300698, 53)

# %%
himanshu.fillna(value='na',axis=0,inplace=True)

# %%
himanshu['Bridge Highway Name'].value_counts()
# Out:
# na                                            300455
# FDR Dr                                            33
# Belt Pkwy                                         30
# BQE/Gowanus Expwy                                 27
# Staten Island Expwy                               21
# Cross Bronx Expwy                                 19
# Battery Park Underpass                            15
# Long Island Expwy                                 12
# Henry Hudson Pkwy/Rt 9A                           10
# West Street                                        7
# Grand Central Pkwy                                 7
# Bronx River Pkwy                                   7
# Major Deegan Expwy                                 7
# Harlem River Dr                                    6
# Van Wyck Expwy                                     6
# Jackie Robinson/Interboro Pkwy                     6
# Whitestone Expwy                                   4
# Prospect Expwy                                     4
# Park Ave Tunnel - E 34th St./Grand Central         3
# First Ave Tunnel - UN Plaza                        3
# Bruckner Expwy                                     2
# Cross Island Pkwy                                  2
# Sheridan Expwy                                     2
# FDR Southbound                                     2
# Richmond Pkwy/Korean War Vets                      2
# Hutchinson River Pkwy                              2
# Third Ave Br - Fifth St Basin                      1
# Nassau Expwy                                       1
# Third Ave Br - E 129th St                          1
# Clearview Expwy                                    1
# Name: Bridge Highway Name, dtype: int64

# %%
himanshu.head()
# Out:
#    Unique Key      Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 23:59  1/1/2016 0:55   NYPD
# 1    32309934  12/31/2015 23:59  1/1/2016 1:26   NYPD
# 2    32309159  12/31/2015 23:59  1/1/2016 4:51   NYPD
# 3    32305098  12/31/2015 23:57  1/1/2016 7:43   NYPD
# 4    32306529  12/31/2015 23:56  1/1/2016 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0    71 VERMILYEA AVENUE  ...                  na                       na
# 1        27-07 23 AVENUE  ...                  na                       na
# 2  2897 VALENTINE AVENUE  ...                  na                       na
# 3    2940 BAISLEY AVENUE  ...                  na                       na
# 4          87-14 57 ROAD  ...                  na                       na
#
#   Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 0        na                     na              na              na
# 1        na                     na              na              na
# 2        na                     na              na              na
# 3        na                     na              na              na
# 4        na                     na              na              na
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                  na  40.865682 -73.923501
# 1                  na  40.775945 -73.915094
# 2                  na  40.870325 -73.888525
# 3                  na  40.835994 -73.828379
# 4                  na   40.73306  -73.87417
#
#                                    Location
# 0   (40.86568153633767, -73.92350095571744)
# 1  (40.775945312321085, -73.91509393898605)
# 2  (40.870324522111424, -73.88852464418646)
# 3   (40.83599404683083, -73.82837939584206)
# 4  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
himanshu.isnull().sum()
# Out:
# Unique Key                        0
# Created Date                      0
# Closed Date                       0
# Agency                            0
# Agency Name                       0
# Complaint Type                    0
# Descriptor                        0
# Location Type                     0
# Incident Zip                      0
# Incident Address                  0
# Street Name                       0
# Cross Street 1                    0
# Cross Street 2                    0
# Intersection Street 1             0
# Intersection Street 2             0
# Address Type                      0
# City                              0
# Landmark                          0
# Facility Type                     0
# Status                            0
# Due Date                          0
# Resolution Description            0
# Resolution Action Updated Date    0
# Community Board                   0
# Borough                           0
# X Coordinate (State Plane)        0
# Y Coordinate (State Plane)        0
# Park Facility Name                0
# Park Borough                      0
# School Name                       0
# School Number                     0
# School Region                     0
# School Code                       0
# School Phone Number               0
# School Address                    0
# School City                       0
# School State                      0
# School Zip                        0
# School Not Found                  0
# School or Citywide Complaint      0
# Vehicle Type                      0
# Taxi Company Borough              0
# Taxi Pick Up Location             0
# Bridge Highway Name               0
# Bridge Highway Direction          0
# Road Ramp                         0
# Bridge Highway Segment            0
# Garage Lot Name                   0
# Ferry Direction                   0
# Ferry Terminal Name               0
# Latitude                          0
# Longitude                         0
# Location                          0
# dtype: int64

# %%
request= himanshu['Complaint Type'].value_counts()
print(request)
# Out:
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Agency Issues                    6
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1
# Name: Complaint Type, dtype: int64

# %%
from datetime import date

# %%
himanshu['Created Date'].dtype
# Out:
# dtype('O')

# %%
himanshu['Created Date'] =pd.to_datetime(himanshu['Created Date'])

# %%
himanshu['Created Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
himanshu['Closed Date'] =pd.to_datetime(himanshu['Closed Date'] ,errors='coerce')

# %%
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0    71 VERMILYEA AVENUE  ...                  na                       na
# 1        27-07 23 AVENUE  ...                  na                       na
# 2  2897 VALENTINE AVENUE  ...                  na                       na
# 3    2940 BAISLEY AVENUE  ...                  na                       na
# 4          87-14 57 ROAD  ...                  na                       na
#
#   Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 0        na                     na              na              na
# 1        na                     na              na              na
# 2        na                     na              na              na
# 3        na                     na              na              na
# 4        na                     na              na              na
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                  na  40.865682 -73.923501
# 1                  na  40.775945 -73.915094
# 2                  na  40.870325 -73.888525
# 3                  na  40.835994 -73.828379
# 4                  na   40.73306  -73.87417
#
#                                    Location
# 0   (40.86568153633767, -73.92350095571744)
# 1  (40.775945312321085, -73.91509393898605)
# 2  (40.870324522111424, -73.88852464418646)
# 3   (40.83599404683083, -73.82837939584206)
# 4  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
himanshu['Closed Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
     himanshu['Request_Closing_Time'] = himanshu['Closed Date'] - himanshu['Created Date']

# %%
himanshu['Request_Closing_Time'].dtypes
# Out:
# dtype('<m8[ns]')

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
himanshu['Complaint Type'].unique()
# Out:
# array(['Noise - Street/Sidewalk', 'Blocked Driveway', 'Illegal Parking',
#        'Derelict Vehicle', 'Noise - Commercial',
#        'Noise - House of Worship', 'Posting Advertisement',
#        'Noise - Vehicle', 'Animal Abuse', 'Vending', 'Traffic',
#        'Drinking', 'Bike/Roller/Skate Chronic', 'Panhandling',
#        'Noise - Park', 'Homeless Encampment', 'Urinating in Public',
#        'Graffiti', 'Disorderly Youth', 'Illegal Fireworks',
#        'Ferry Complaint', 'Agency Issues', 'Squeegee', 'Animal in a Park'],
#       dtype=object)

# %%
himanshu['Descriptor'].unique()
# Out:
# array(['Loud Music/Party', 'No Access', 'Commercial Overnight Parking',
#        'Blocked Sidewalk', 'Posted Parking Sign Violation',
#        'Blocked Hydrant', 'With License Plate', 'Partial Access',
#        'Unauthorized Bus Layover', 'Double Parked Blocking Vehicle',
#        'Double Parked Blocking Traffic', 'Vehicle', 'Loud Talking',
#        'Banging/Pounding', 'Car/Truck Music', 'Tortured',
#        'In Prohibited Area', 'Congestion/Gridlock', 'Neglected',
#        'Car/Truck Horn', 'In Public', 'Other (complaint details)', 'na',
#        'No Shelter', 'Truck Route Violation', 'Unlicensed',
#        'Overnight Commercial Storage', 'Engine Idling',
#        'After Hours - Licensed Est', 'Detached Trailer',
#        'Underage - Licensed Est', 'Chronic Stoplight Violation',
#        'Loud Television', 'Chained', 'Building', 'In Car',
#        'Police Report Requested', 'Chronic Speeding',
#        'Playing in Unsuitable Place', 'Drag Racing',
#        'Police Report Not Requested', 'Nuisance/Truant', 'Homeless Issue',
#        'Language Access Complaint', 'Disruptive Passenger',
#        'Animal Waste'], dtype=object)

# %%
complaint_type= himanshu.groupby('Complaint Type')['Descriptor']
print(complaint_type.first())
# Out:
# Complaint Type
# Agency Issues                   Language Access Complaint
# Animal Abuse                                     Tortured
# Animal in a Park                             Animal Waste
# Bike/Roller/Skate Chronic                              na
# Blocked Driveway                                No Access
# Derelict Vehicle                       With License Plate
# Disorderly Youth              Playing in Unsuitable Place
# Drinking                                        In Public
# Ferry Complaint                            Homeless Issue
# Graffiti                          Police Report Requested
# Homeless Encampment                                    na
# Illegal Fireworks                                      na
# Illegal Parking              Commercial Overnight Parking
# Noise - Commercial                       Loud Music/Party
# Noise - House of Worship                 Loud Music/Party
# Noise - Park                             Loud Music/Party
# Noise - Street/Sidewalk                  Loud Music/Party
# Noise - Vehicle                           Car/Truck Music
# Panhandling                                            na
# Posting Advertisement                             Vehicle
# Squeegee                                               na
# Traffic                               Congestion/Gridlock
# Urinating in Public                                    na
# Vending                                In Prohibited Area
# Name: Descriptor, dtype: object

# %%
himanshu.describe()
# Out:
#          Unique Key       Request_Closing_Time
# count  3.006980e+05                     298534
# mean   3.130054e+07  0 days 04:18:51.817615413
# std    5.738547e+05  0 days 06:05:22.155510708
# min    3.027948e+07            0 days 00:01:00
# 25%    3.080118e+07            0 days 01:17:00
# 50%    3.130436e+07            0 days 02:43:00
# 75%    3.178446e+07            0 days 05:21:00
# max    3.231065e+07           24 days 16:53:00

# %%
sns.jointplot(x='Created Date',y='Complaint Type',data=himanshu,kind='hist',color='r',height=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
himanshu.drop(['Request_Closing_Time'],axis=1,inplace=True)

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 0    71 VERMILYEA AVENUE  ...                  na                       na
# 1        27-07 23 AVENUE  ...                  na                       na
# 2  2897 VALENTINE AVENUE  ...                  na                       na
# 3    2940 BAISLEY AVENUE  ...                  na                       na
# 4          87-14 57 ROAD  ...                  na                       na
#
#   Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 0        na                     na              na              na
# 1        na                     na              na              na
# 2        na                     na              na              na
# 3        na                     na              na              na
# 4        na                     na              na              na
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                  na  40.865682 -73.923501
# 1                  na  40.775945 -73.915094
# 2                  na  40.870325 -73.888525
# 3                  na  40.835994 -73.828379
# 4                  na   40.73306  -73.87417
#
#                                    Location
# 0   (40.86568153633767, -73.92350095571744)
# 1  (40.775945312321085, -73.91509393898605)
# 2  (40.870324522111424, -73.88852464418646)
# 3   (40.83599404683083, -73.82837939584206)
# 4  (40.733059618956815, -73.87416975810375)
#
# [5 rows x 53 columns]

# %%
himanshu['Request_Closing_Time'] = himanshu['Closed Date'] - himanshu['Created Date']

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
himanshu['Request_Closing_Time'].dtype
# Out:
# dtype('<m8[ns]')

# %%
himanshu.describe()
# Out:
#          Unique Key       Request_Closing_Time
# count  3.006980e+05                     298534
# mean   3.130054e+07  0 days 04:18:51.817615413
# std    5.738547e+05  0 days 06:05:22.155510708
# min    3.027948e+07            0 days 00:01:00
# 25%    3.080118e+07            0 days 01:17:00
# 50%    3.130436e+07            0 days 02:43:00
# 75%    3.178446e+07            0 days 05:21:00
# max    3.231065e+07           24 days 16:53:00

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
complaint=himanshu.groupby('Request_Closing_Time')['Complaint Type']
print(complaint.sum())
# Out:
# Request_Closing_Time
# 0 days 00:01:00                                    Noise - Commercial
# 0 days 00:02:00     Noise - CommercialPosting AdvertisementIllegal...
# 0 days 00:03:00     VendingVendingIllegal ParkingNoise - Commercia...
# 0 days 00:04:00     Noise - CommercialNoise - CommercialIllegal Pa...
# 0 days 00:05:00     Noise - CommercialNoise - CommercialBlocked Dr...
#                                           ...
# 9 days 07:22:00                                      Derelict Vehicle
# 14 days 00:51:00                                     Animal in a Park
# 21 days 15:16:00                                         Animal Abuse
# 24 days 01:21:00                                      Illegal Parking
# 24 days 16:53:00                              Noise - Street/Sidewalk
# Name: Complaint Type, Length: 3153, dtype: object

# %%
sns.countplot(himanshu['Complaint Type'])
plt.xticks(rotation="vertical");
# Out:
# c:\Users\abxc\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.histplot(x=himanshu['Descriptor'],binwidth=5,element='bars',binrange=(0,25))
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(x='Closed Date',y='Complaint Type',data=himanshu,)
plt.xticks(rotation='vertical');

# %%
sns.scatterplot(x='Created Date',y='Complaint Type',data=himanshu,)
plt.xticks(rotation='vertical');

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
complaint_type=himanshu['Complaint Type'].value_counts()

# %%
himanshu_new2=pd.DataFrame(complaint_type)

# %%
himanshu_new2.head()
# Out:
#                          Complaint Type
# Blocked Driveway                  77044
# Illegal Parking                   75361
# Noise - Street/Sidewalk           48612
# Noise - Commercial                35577
# Derelict Vehicle                  17718

# %%
himanshu_new2.columns
# Out:
# Index(['Complaint Type'], dtype='object')

# %%
himanshu_new2['Percentage'] = np.around((himanshu_new2['Complaint Type']/himanshu_new2['Complaint Type'].sum())*100,decimals=2)
himanshu_new2['Percentage']
# Out:
# Blocked Driveway             25.62
# Illegal Parking              25.06
# Noise - Street/Sidewalk      16.17
# Noise - Commercial           11.83
# Derelict Vehicle              5.89
# Noise - Vehicle               5.68
# Animal Abuse                  2.59
# Traffic                       1.50
# Homeless Encampment           1.47
# Noise - Park                  1.34
# Vending                       1.26
# Drinking                      0.43
# Noise - House of Worship      0.31
# Posting Advertisement         0.22
# Urinating in Public           0.20
# Bike/Roller/Skate Chronic     0.14
# Panhandling                   0.10
# Disorderly Youth              0.10
# Illegal Fireworks             0.06
# Graffiti                      0.04
# Agency Issues                 0.00
# Squeegee                      0.00
# Ferry Complaint               0.00
# Animal in a Park              0.00
# Name: Percentage, dtype: float64

# %%
himanshu_new2.head()
# Out:
#                          Complaint Type  Percentage
# Blocked Driveway                  77044       25.62
# Illegal Parking                   75361       25.06
# Noise - Street/Sidewalk           48612       16.17
# Noise - Commercial                35577       11.83
# Derelict Vehicle                  17718        5.89

# %%
himanshu_new2.reset_index(inplace=True)

# %%
himanshu_new2.head()
# Out:
#                      index  Complaint Type  Percentage
# 0         Blocked Driveway           77044       25.62
# 1          Illegal Parking           75361       25.06
# 2  Noise - Street/Sidewalk           48612       16.17
# 3       Noise - Commercial           35577       11.83
# 4         Derelict Vehicle           17718        5.89

# %%
himanshu_new2.rename(columns={'index':'complaint type','Complaint Type':'count'},inplace=True)

# %%
himanshu_new2.head()
# Out:
#             complaint type  count  Percentage
# 0         Blocked Driveway  77044       25.62
# 1          Illegal Parking  75361       25.06
# 2  Noise - Street/Sidewalk  48612       16.17
# 3       Noise - Commercial  35577       11.83
# 4         Derelict Vehicle  17718        5.89

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=himanshu_new2['complaint type'],y=himanshu_new2['Percentage'],data=himanshu_new2)

plt.title('Proportion of different complaint type (major)')
plt.xticks(rotation=90)
plt.show()

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
data_descriptor = np.around(((himanshu['Descriptor'].value_counts()*100) / himanshu['Descriptor'].value_counts().sum()),
                            decimals=2)
data_descriptor = data_descriptor.to_frame()
data_descriptor = data_descriptor.rename(columns={'Descriptor':'Percentage'})
data_descriptor['Descriptor'] = data_descriptor.index
cols = data_descriptor.columns.tolist()
cols = cols[-1:]+cols[:-1]
data_descriptor = data_descriptor[cols]
data_descriptor = data_descriptor[(data_descriptor.Percentage) >= 2.0]
data_descriptor = data_descriptor.reset_index()
data_descriptor = data_descriptor.drop(columns=['index'],axis=1)
data_descriptor
# Out:
#                       Descriptor  Percentage
# 0               Loud Music/Party       20.43
# 1                      No Access       18.95
# 2  Posted Parking Sign Violation        7.46
# 3                   Loud Talking        7.18
# 4                 Partial Access        6.67
# 5             With License Plate        5.89
# 6                Blocked Hydrant        5.35
# 7   Commercial Overnight Parking        4.05
# 8                Car/Truck Music        3.75
# 9               Blocked Sidewalk        3.70

# %%
data_city = np.around(((himanshu['City'].value_counts()*100) / himanshu['City'].value_counts().sum()),
                            decimals=2)
data_city = data_city.to_frame()
data_city = data_city.rename(columns={'City':'Percentage'})
data_city['City'] = data_city.index
cols = data_city.columns.tolist()
cols = cols[-1:]+cols[:-1]
data_city = data_city[cols]
data_city = data_city[(data_city.Percentage) >= 1.0]
data_city = data_city.reset_index()
data_city = data_city.drop(columns=['index'],axis=1)
data_city
# Out:
#             City  Percentage
# 0       BROOKLYN       32.69
# 1       NEW YORK       21.95
# 2          BRONX       13.54
# 3  STATEN ISLAND        4.10
# 4        JAMAICA        2.43
# 5        ASTORIA        2.11
# 6       FLUSHING        1.99
# 7      RIDGEWOOD        1.72
# 8         CORONA        1.43
# 9       WOODSIDE        1.18

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
himanshu.City
# Out:
# 0              NEW YORK
# 1               ASTORIA
# 2                 BRONX
# 3                 BRONX
# 4              ELMHURST
#               ...
# 300693               na
# 300694    RICHMOND HILL
# 300695         BROOKLYN
# 300696            BRONX
# 300697         NEW YORK
# Name: City, Length: 300698, dtype: object

# %%
himanshu.shape
# Out:
# (300698, 54)

# %%
himanshu['Due Date']
# Out:
# 0          1/1/2016 7:59
# 1          1/1/2016 7:59
# 2          1/1/2016 7:59
# 3          1/1/2016 7:57
# 4          1/1/2016 7:56
#                ...
# 300693    3/29/2015 8:33
# 300694    3/29/2015 8:33
# 300695    3/29/2015 8:33
# 300696    3/29/2015 8:33
# 300697    3/29/2015 8:33
# Name: Due Date, Length: 300698, dtype: object

# %%
data_address_type = np.around(((himanshu['Address Type'].value_counts()*100) /himanshu['Address Type'].value_counts().sum()),
                            decimals=2)
data_address_type = data_address_type.to_frame()
data_address_type = data_address_type.rename(columns={'Address Type':'Percentage'})
data_address_type['Address Type'] = data_address_type.index
cols = data_address_type.columns.tolist()
cols = cols[-1:]+cols[:-1]
data_address_type = data_address_type[cols]
#data_address_type = data_address_type[(data_address_type.Percentage) >= 1.0]
data_address_type = data_address_type.reset_index()
data_address_type = data_address_type.drop(columns=['index'],axis=1)
data_address_type
# Out:
#    Address Type  Percentage
# 0       ADDRESS       79.36
# 1  INTERSECTION       14.42
# 2     BLOCKFACE        4.00
# 3       LATLONG        1.17
# 4            na        0.94
# 5     PLACENAME        0.12

# %%
data_location_type = np.around(((himanshu['Location Type'].value_counts()*100) / himanshu['Location Type'].value_counts().sum()),
                            decimals=2)
data_location_type = data_location_type.to_frame()
data_location_type = data_location_type.rename(columns={'Location Type':'Percentage'})
data_location_type['Location Type'] = data_location_type.index
cols = data_location_type.columns.tolist()
cols = cols[-1:]+cols[:-1]
data_location_type = data_location_type[cols]
data_location_type = data_location_type[(data_location_type.Percentage) >= 0.1]
data_location_type = data_location_type.reset_index()
data_location_type = data_location_type.drop(columns=['index'],axis=1)
data_location_type
# Out:
#                 Location Type  Percentage
# 0             Street/Sidewalk       82.91
# 1            Store/Commercial        6.78
# 2         Club/Bar/Restaurant        5.77
# 3  Residential Building/House        2.31
# 4             Park/Playground        1.59
# 5            House of Worship        0.31

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
descriptor = sns.barplot(ax=ax[0,0],x=data_descriptor.Descriptor,y=data_descriptor.Percentage,)
descriptor.set_xticklabels(descriptor.get_xticklabels(), rotation=30, ha="right")

location_type = sns.barplot(ax=ax[0,1],x=data_location_type['Location Type'],y=data_location_type.Percentage,)
location_type.set_xticklabels(location_type.get_xticklabels(), rotation=30, ha="right")

city = sns.barplot(ax=ax[1,0],x=data_city['City'],y=data_city.Percentage,)
city.set_xticklabels(city.get_xticklabels(), rotation=30, ha="right")

address = sns.barplot(ax=ax[1,1],x=data_address_type['Address Type'],y=data_address_type.Percentage,)
address.set_xticklabels(address.get_xticklabels(), rotation=30, ha="right")
# Out:
# [Text(0, 0, 'ADDRESS'),
#  Text(1, 0, 'INTERSECTION'),
#  Text(2, 0, 'BLOCKFACE'),
#  Text(3, 0, 'LATLONG'),
#  Text(4, 0, 'na'),
#  Text(5, 0, 'PLACENAME')]

# %%
himanshu['Address Type'].unique()
# Out:
# array(['ADDRESS', 'na', 'INTERSECTION', 'LATLONG', 'BLOCKFACE',
#        'PLACENAME'], dtype=object)

# %%
himanshu.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
#        'Bridge Highway Segment', 'Garage Lot Name', 'Ferry Direction',
#        'Ferry Terminal Name', 'Latitude', 'Longitude', 'Location',
#        'Request_Closing_Time'],
#       dtype='object')

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Direction Road Ramp  \
# 0    71 VERMILYEA AVENUE  ...                       na        na
# 1        27-07 23 AVENUE  ...                       na        na
# 2  2897 VALENTINE AVENUE  ...                       na        na
# 3    2940 BAISLEY AVENUE  ...                       na        na
# 4          87-14 57 ROAD  ...                       na        na
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                     na              na              na                  na
# 1                     na              na              na                  na
# 2                     na              na              na                  na
# 3                     na              na              na                  na
# 4                     na              na              na                  na
#
#     Latitude  Longitude                                  Location  \
# 0  40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1  40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2  40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3  40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4   40.73306  -73.87417  (40.733059618956815, -73.87416975810375)
#
#   Request_Closing_Time
# 0      0 days 00:56:00
# 1      0 days 01:27:00
# 2      0 days 04:52:00
# 3      0 days 07:46:00
# 4      0 days 03:28:00
#
# [5 rows x 54 columns]

# %%
himanshu['Request_Closing_Time'].dtype
# Out:
# dtype('<m8[ns]')

# %%
himanshu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 54 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  datetime64[ns]
#  2   Closed Date                     298534 non-null  datetime64[ns]
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      300698 non-null  object
#  7   Location Type                   300698 non-null  object
#  8   Incident Zip                    300698 non-null  object
#  9   Incident Address                300698 non-null  object
#  10  Street Name                     300698 non-null  object
#  11  Cross Street 1                  300698 non-null  object
#  12  Cross Street 2                  300698 non-null  object
#  13  Intersection Street 1           300698 non-null  object
#  14  Intersection Street 2           300698 non-null  object
#  15  Address Type                    300698 non-null  object
#  16  City                            300698 non-null  object
#  17  Landmark                        300698 non-null  object
#  18  Facility Type                   300698 non-null  object
#  19  Status                          300698 non-null  object
#  20  Due Date                        300698 non-null  object
#  21  Resolution Description          300698 non-null  object
#  22  Resolution Action Updated Date  300698 non-null  object
#  23  Community Board                 300698 non-null  object
#  24  Borough                         300698 non-null  object
#  25  X Coordinate (State Plane)      300698 non-null  object
#  26  Y Coordinate (State Plane)      300698 non-null  object
#  27  Park Facility Name              300698 non-null  object
#  28  Park Borough                    300698 non-null  object
#  29  School Name                     300698 non-null  object
#  30  School Number                   300698 non-null  object
#  31  School Region                   300698 non-null  object
#  32  School Code                     300698 non-null  object
#  33  School Phone Number             300698 non-null  object
#  34  School Address                  300698 non-null  object
#  35  School City                     300698 non-null  object
#  36  School State                    300698 non-null  object
#  37  School Zip                      300698 non-null  object
#  38  School Not Found                300698 non-null  object
#  39  School or Citywide Complaint    300698 non-null  object
#  40  Vehicle Type                    300698 non-null  object
#  41  Taxi Company Borough            300698 non-null  object
#  42  Taxi Pick Up Location           300698 non-null  object
#  43  Bridge Highway Name             300698 non-null  object
#  44  Bridge Highway Direction        300698 non-null  object
#  45  Road Ramp                       300698 non-null  object
#  46  Bridge Highway Segment          300698 non-null  object
#  47  Garage Lot Name                 300698 non-null  object
#  48  Ferry Direction                 300698 non-null  object
#  49  Ferry Terminal Name             300698 non-null  object
#  50  Latitude                        300698 non-null  object
#  51  Longitude                       300698 non-null  object
#  52  Location                        300698 non-null  object
#  53  Request_Closing_Time            298534 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(50), timedelta64[ns](1)
# memory usage: 123.9+ MB

# %%
himanshu['Request_Closing_Time_new'] = himanshu['Closed Date'] - himanshu['Created Date']

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Road Ramp Bridge Highway Segment  \
# 0    71 VERMILYEA AVENUE  ...        na                     na
# 1        27-07 23 AVENUE  ...        na                     na
# 2  2897 VALENTINE AVENUE  ...        na                     na
# 3    2940 BAISLEY AVENUE  ...        na                     na
# 4          87-14 57 ROAD  ...        na                     na
#
#   Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0              na              na                  na  40.865682 -73.923501
# 1              na              na                  na  40.775945 -73.915094
# 2              na              na                  na  40.870325 -73.888525
# 3              na              na                  na  40.835994 -73.828379
# 4              na              na                  na   40.73306  -73.87417
#
#                                    Location Request_Closing_Time  \
# 0   (40.86568153633767, -73.92350095571744)      0 days 00:56:00
# 1  (40.775945312321085, -73.91509393898605)      0 days 01:27:00
# 2  (40.870324522111424, -73.88852464418646)      0 days 04:52:00
# 3   (40.83599404683083, -73.82837939584206)      0 days 07:46:00
# 4  (40.733059618956815, -73.87416975810375)      0 days 03:28:00
#
#   Request_Closing_Time_new
# 0          0 days 00:56:00
# 1          0 days 01:27:00
# 2          0 days 04:52:00
# 3          0 days 07:46:00
# 4          0 days 03:28:00
#
# [5 rows x 55 columns]

# %%
himanshu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 55 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  datetime64[ns]
#  2   Closed Date                     298534 non-null  datetime64[ns]
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      300698 non-null  object
#  7   Location Type                   300698 non-null  object
#  8   Incident Zip                    300698 non-null  object
#  9   Incident Address                300698 non-null  object
#  10  Street Name                     300698 non-null  object
#  11  Cross Street 1                  300698 non-null  object
#  12  Cross Street 2                  300698 non-null  object
#  13  Intersection Street 1           300698 non-null  object
#  14  Intersection Street 2           300698 non-null  object
#  15  Address Type                    300698 non-null  object
#  16  City                            300698 non-null  object
#  17  Landmark                        300698 non-null  object
#  18  Facility Type                   300698 non-null  object
#  19  Status                          300698 non-null  object
#  20  Due Date                        300698 non-null  object
#  21  Resolution Description          300698 non-null  object
#  22  Resolution Action Updated Date  300698 non-null  object
#  23  Community Board                 300698 non-null  object
#  24  Borough                         300698 non-null  object
#  25  X Coordinate (State Plane)      300698 non-null  object
#  26  Y Coordinate (State Plane)      300698 non-null  object
#  27  Park Facility Name              300698 non-null  object
#  28  Park Borough                    300698 non-null  object
#  29  School Name                     300698 non-null  object
#  30  School Number                   300698 non-null  object
#  31  School Region                   300698 non-null  object
#  32  School Code                     300698 non-null  object
#  33  School Phone Number             300698 non-null  object
#  34  School Address                  300698 non-null  object
#  35  School City                     300698 non-null  object
#  36  School State                    300698 non-null  object
#  37  School Zip                      300698 non-null  object
#  38  School Not Found                300698 non-null  object
#  39  School or Citywide Complaint    300698 non-null  object
#  40  Vehicle Type                    300698 non-null  object
#  41  Taxi Company Borough            300698 non-null  object
#  42  Taxi Pick Up Location           300698 non-null  object
#  43  Bridge Highway Name             300698 non-null  object
#  44  Bridge Highway Direction        300698 non-null  object
#  45  Road Ramp                       300698 non-null  object
#  46  Bridge Highway Segment          300698 non-null  object
#  47  Garage Lot Name                 300698 non-null  object
#  48  Ferry Direction                 300698 non-null  object
#  49  Ferry Terminal Name             300698 non-null  object
#  50  Latitude                        300698 non-null  object
#  51  Longitude                       300698 non-null  object
#  52  Location                        300698 non-null  object
#  53  Request_Closing_Time            298534 non-null  timedelta64[ns]
#  54  Request_Closing_Time_new        298534 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), int64(1), object(50), timedelta64[ns](2)
# memory usage: 126.2+ MB

# %%
himanshu['Request_Closing_Time']=himanshu['Request_Closing_Time'].astype(str)

# %%
himanshu['Request_Closing_Time']=pd.to_timedelta(himanshu["Request_Closing_Time"])

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Road Ramp Bridge Highway Segment  \
# 0    71 VERMILYEA AVENUE  ...        na                     na
# 1        27-07 23 AVENUE  ...        na                     na
# 2  2897 VALENTINE AVENUE  ...        na                     na
# 3    2940 BAISLEY AVENUE  ...        na                     na
# 4          87-14 57 ROAD  ...        na                     na
#
#   Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0              na              na                  na  40.865682 -73.923501
# 1              na              na                  na  40.775945 -73.915094
# 2              na              na                  na  40.870325 -73.888525
# 3              na              na                  na  40.835994 -73.828379
# 4              na              na                  na   40.73306  -73.87417
#
#                                    Location Request_Closing_Time  \
# 0   (40.86568153633767, -73.92350095571744)      0 days 00:56:00
# 1  (40.775945312321085, -73.91509393898605)      0 days 01:27:00
# 2  (40.870324522111424, -73.88852464418646)      0 days 04:52:00
# 3   (40.83599404683083, -73.82837939584206)      0 days 07:46:00
# 4  (40.733059618956815, -73.87416975810375)      0 days 03:28:00
#
#   Request_Closing_Time_new
# 0          0 days 00:56:00
# 1          0 days 01:27:00
# 2          0 days 04:52:00
# 3          0 days 07:46:00
# 4          0 days 03:28:00
#
# [5 rows x 55 columns]

# %%
himanshu['request_closing_hours']=himanshu['Request_Closing_Time']/pd.Timedelta(hours=1)

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Segment Garage Lot Name  \
# 0    71 VERMILYEA AVENUE  ...                     na              na
# 1        27-07 23 AVENUE  ...                     na              na
# 2  2897 VALENTINE AVENUE  ...                     na              na
# 3    2940 BAISLEY AVENUE  ...                     na              na
# 4          87-14 57 ROAD  ...                     na              na
#
#   Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0              na                  na  40.865682 -73.923501
# 1              na                  na  40.775945 -73.915094
# 2              na                  na  40.870325 -73.888525
# 3              na                  na  40.835994 -73.828379
# 4              na                  na   40.73306  -73.87417
#
#                                    Location Request_Closing_Time  \
# 0   (40.86568153633767, -73.92350095571744)      0 days 00:56:00
# 1  (40.775945312321085, -73.91509393898605)      0 days 01:27:00
# 2  (40.870324522111424, -73.88852464418646)      0 days 04:52:00
# 3   (40.83599404683083, -73.82837939584206)      0 days 07:46:00
# 4  (40.733059618956815, -73.87416975810375)      0 days 03:28:00
#
#   Request_Closing_Time_new request_closing_hours
# 0          0 days 00:56:00              0.933333
# 1          0 days 01:27:00              1.450000
# 2          0 days 04:52:00              4.866667
# 3          0 days 07:46:00              7.766667
# 4          0 days 03:28:00              3.466667
#
# [5 rows x 56 columns]

# %%
himanshu.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:00 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:00 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:00 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:00 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:00 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk      10034.0
# 1                     No Access  Street/Sidewalk      11105.0
# 2                     No Access  Street/Sidewalk      10458.0
# 3  Commercial Overnight Parking  Street/Sidewalk      10461.0
# 4              Blocked Sidewalk  Street/Sidewalk      11373.0
#
#         Incident Address  ... Bridge Highway Segment Garage Lot Name  \
# 0    71 VERMILYEA AVENUE  ...                     na              na
# 1        27-07 23 AVENUE  ...                     na              na
# 2  2897 VALENTINE AVENUE  ...                     na              na
# 3    2940 BAISLEY AVENUE  ...                     na              na
# 4          87-14 57 ROAD  ...                     na              na
#
#   Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0              na                  na  40.865682 -73.923501
# 1              na                  na  40.775945 -73.915094
# 2              na                  na  40.870325 -73.888525
# 3              na                  na  40.835994 -73.828379
# 4              na                  na   40.73306  -73.87417
#
#                                    Location Request_Closing_Time  \
# 0   (40.86568153633767, -73.92350095571744)      0 days 00:56:00
# 1  (40.775945312321085, -73.91509393898605)      0 days 01:27:00
# 2  (40.870324522111424, -73.88852464418646)      0 days 04:52:00
# 3   (40.83599404683083, -73.82837939584206)      0 days 07:46:00
# 4  (40.733059618956815, -73.87416975810375)      0 days 03:28:00
#
#   Request_Closing_Time_new request_closing_hours
# 0          0 days 00:56:00              0.933333
# 1          0 days 01:27:00              1.450000
# 2          0 days 04:52:00              4.866667
# 3          0 days 07:46:00              7.766667
# 4          0 days 03:28:00              3.466667
#
# [5 rows x 56 columns]

# %%
Average_time = np.around((himanshu['request_closing_hours'].mean()),decimals=2)
print('Average time gap between logging the complaint and problem solved = ',Average_time, 'hour')
Central_val = np.around((himanshu['request_closing_hours'].median()),decimals=2)
print('Central value of the distribution = ',Central_val, 'hour')
Most_occoor = np.around((himanshu['request_closing_hours'].mode()),decimals=2)
print('Most occered value = ',Most_occoor, 'hour')
stand_dev = np.around((himanshu['request_closing_hours'].std()),decimals=2)
print('Deviation is = ',stand_dev)
# Out:
# Average time gap between logging the complaint and problem solved =  4.31 hour
# Central value of the distribution =  2.72 hour
# Most occered value =  0    0.6
# Name: request_closing_hours, dtype: float64 hour
# Deviation is =  6.09

# %%
data_place_CType_RCTime = himanshu[['City','Complaint Type','Request_Closing_Time']]
data_place_CType_RCTime.dropna(subset = ['City','Complaint Type','Request_Closing_Time'], inplace = True)
data_place_CType_RCTime['hours']=himanshu['request_closing_hours']
data_place_CType_RCTime.head()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_7512\3778436596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_place_CType_RCTime.dropna(subset = ['City','Complaint Type','Request_Closing_Time'], inplace = True)
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_7512\3778436596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_place_CType_RCTime['hours']=himanshu['request_closing_hours']
#        City           Complaint Type Request_Closing_Time     hours
# 0  NEW YORK  Noise - Street/Sidewalk      0 days 00:56:00  0.933333
# 1   ASTORIA         Blocked Driveway      0 days 01:27:00  1.450000
# 2     BRONX         Blocked Driveway      0 days 04:52:00  4.866667
# 3     BRONX          Illegal Parking      0 days 07:46:00  7.766667
# 4  ELMHURST          Illegal Parking      0 days 03:28:00  3.466667

# %%
conditions = [data_place_CType_RCTime['hours'] <= 0.5,
             (0.50 < data_place_CType_RCTime['hours']) & (data_place_CType_RCTime['hours'] <= 1.00),
             (1.00 < data_place_CType_RCTime['hours']) & (data_place_CType_RCTime['hours'] <= 2.00),
             (2.00 < data_place_CType_RCTime['hours']) & (data_place_CType_RCTime['hours'] <= 6.00),
             (6.00 < data_place_CType_RCTime['hours']) & (data_place_CType_RCTime['hours'] <= 10.00),
             (10.00 < data_place_CType_RCTime['hours'])]

choices = ['Super fast','Very fast','Fast','Normal','Slow','Super Slow']

data_place_CType_RCTime['Solution Status'] = np.select(conditions,choices)
data_place_CType_RCTime.head()
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_7512\4174191950.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_place_CType_RCTime['Solution Status'] = np.select(conditions,choices)
#        City           Complaint Type Request_Closing_Time     hours  \
# 0  NEW YORK  Noise - Street/Sidewalk      0 days 00:56:00  0.933333
# 1   ASTORIA         Blocked Driveway      0 days 01:27:00  1.450000
# 2     BRONX         Blocked Driveway      0 days 04:52:00  4.866667
# 3     BRONX          Illegal Parking      0 days 07:46:00  7.766667
# 4  ELMHURST          Illegal Parking      0 days 03:28:00  3.466667
#
#   Solution Status
# 0       Very fast
# 1            Fast
# 2          Normal
# 3            Slow
# 4          Normal

# %%
data_place_CType_RCTime['Solution Status'].value_counts()
# Out:
# Normal        119062
# Fast           58554
# Slow           38161
# Very fast      33476
# Super Slow     25009
# Super fast     24272
# Name: Solution Status, dtype: int64

# %%
data_place_CType_RCTime['Solution Status'].value_counts().plot(kind='bar')
plt.xlabel('Time Status')
plt.ylabel('Counts')
plt.title('Proportion of the fastness of different Solution status')
plt.show()
plt.tight_layout()

# %%
himanshu['Created Date'].head(5)
# Out:
# 0   2015-12-31 23:59:00
# 1   2015-12-31 23:59:00
# 2   2015-12-31 23:59:00
# 3   2015-12-31 23:57:00
# 4   2015-12-31 23:56:00
# Name: Created Date, dtype: datetime64[ns]

# %%
Year_Month_Day = pd.to_datetime(himanshu['Created Date'].dt.date)
Month_Day = pd.DataFrame()
Month_Day['Date'] = pd.to_datetime(Year_Month_Day.dt.date)
Month_Day['Month'] = Year_Month_Day.dt.month
Month_Day['Day'] = Year_Month_Day.dt.day
Month_Day['Day No'] = Month_Day['Date'].dt.weekday
Month_Day['Day Name'] = Month_Day['Day No'].map({0:'Monday',1:'Tuesday',2:'Wednesday',3:'Thursday',4:'Friday',
                                                 5:'Saturday',6:'Sunday'})
Month_Day.sample(20)
# Out:
#              Date  Month  Day  Day No   Day Name
# 49211  2015-11-12     11   12       3   Thursday
# 158682 2015-08-06      8    6       3   Thursday
# 192535 2015-07-06      7    6       0     Monday
# 10332  2015-12-20     12   20       6     Sunday
# 67936  2015-10-25     10   25       6     Sunday
# 173890 2015-07-23      7   23       3   Thursday
# 224917 2015-06-09      6    9       1    Tuesday
# 36018  2015-11-25     11   25       2  Wednesday
# 100495 2015-09-25      9   25       4     Friday
# 275711 2015-04-26      4   26       6     Sunday
# 234127 2015-06-01      6    1       0     Monday
# 291179 2015-04-09      4    9       3   Thursday
# 173497 2015-07-23      7   23       3   Thursday
# 76433  2015-10-17     10   17       5   Saturday
# 128649 2015-09-01      9    1       1    Tuesday
# 266139 2015-05-05      5    5       1    Tuesday
# 40397  2015-11-20     11   20       4     Friday
# 273005 2015-04-28      4   28       1    Tuesday
# 283497 2015-04-18      4   18       5   Saturday
# 72833  2015-10-21     10   21       2  Wednesday

# %%
Month_plot = Month_Day['Month'].value_counts()
Month_plot = Month_plot.to_frame()
Month_plot = Month_plot.rename(columns={'Month':'Counts'})
Month_plot
# Out:
#     Counts
# 5    36437
# 9    35427
# 6    35315
# 8    34956
# 7    34888
# 10   32605
# 11   30773
# 12   30521
# 4    27305
# 3     2471

# %%
Day_plot = Month_Day['Day Name'].value_counts()
Day_plot = Day_plot.to_frame()
Day_plot = Day_plot.rename(columns={'Day Name':'Counts'})
Day_plot
# Out:
#            Counts
# Sunday      47969
# Saturday    47564
# Friday      43995
# Thursday    41342
# Monday      40489
# Wednesday   39788
# Tuesday     39551

# %%
fig, axes = plt.subplots(1,2, figsize=(14,8))

axes[0].pie(Month_plot['Counts'], labels = Month_plot.index,autopct='%1.1f%%')
axes[0].set_title('Complain logged in different months of the year')

axes[1].pie(Day_plot['Counts'], labels = Day_plot.index,autopct='%1.1f%%')
axes[1].set_title('Complain logged in different days of the year')

plt.tight_layout()

# %% [markdown]
# So there is nothing abrupt for the months of lodging complaint. However, a very small amount of complaints recorded in the month of March.
#
# The same observation can be made for the days. But if we look carefully, there is a small increment on the weekends compared to the weekly days.
#
# However, looking at the days of a year might hide some extra information. It is better to check the days of each month of the year.

# %%
Month_Day_grouped = Month_Day.groupby(['Month','Day Name'],as_index=False)['Day No'].count()
Month_Day_grouped_final = Month_Day_grouped.rename(columns={'Day No':'Counts'})
Month_Day_grouped_final.head(15)
# Out:
#     Month   Day Name  Counts
# 0       3     Monday     807
# 1       3     Sunday     802
# 2       3    Tuesday     862
# 3       4     Friday    3565
# 4       4     Monday    3222
# 5       4   Saturday    4227
# 6       4     Sunday    4069
# 7       4   Thursday    4323
# 8       4    Tuesday    3586
# 9       4  Wednesday    4313
# 10      5     Friday    6006
# 11      5     Monday    4792
# 12      5   Saturday    6233
# 13      5     Sunday    6597
# 14      5   Thursday    4290

# %%
Month_Day[( (Month_Day['Month'] == 4) & (Month_Day['Day Name'] == 'Monday') )].count()
# Out:
# Date        3222
# Month       3222
# Day         3222
# Day No      3222
# Day Name    3222
# dtype: int64

# %% [markdown]
# This is just to check whether the grouping operation is done correctly or not.
#
# As you can see below, complaints created in each month for all seven days of the week are plotted. As we already counter that in March there is an abrupt decrement of complaint lodging compared to the other months. And Only three days of a week contributed here. It may contain seven days of the week, but with a very lesser amount. So let's check that to as well from the numbers

# %%
plt.figure(figsize=(20,8))

month_day_plot = sns.barplot(x=Month_Day_grouped_final['Month'], y=Month_Day_grouped_final['Counts'], 
                             hue=Month_Day_grouped_final['Day Name'], data=Month_Day_grouped_final)
month_day_plot.set_xticklabels(month_day_plot.get_xticklabels(), rotation=30, ha="right")
plt.title('Distribution of daily complain in different months of the year')
plt.show()
plt.tight_layout()

# %%
Month_Day_grouped[Month_Day_grouped['Month'] == 3]
# Out:
#    Month Day Name  Day No
# 0      3   Monday     807
# 1      3   Sunday     802
# 2      3  Tuesday     862

# %% [markdown]
# So complaints are recorded only in these three days of March.
#
# And let's have a look quickly at the status of the complaints.

# %%
himanshu['Status'].value_counts().plot(kind='barh')
plt.xlabel('Status')
plt.ylabel('Counts')
plt.title('Proportion of different Solution status')
plt.show()
plt.tight_layout()

# %% [markdown]
# Ordering the complaint types based on the average ‘Request_Closing_Time’ (converted into integer and kept in column 'DeltaT(in_hr.)') and grouping them for different locations (such as 'City').

# %%
Complaint_City_AvgTime_grouped = data_place_CType_RCTime.groupby(['City','Complaint Type']).agg({'hours':'mean'})
Complaint_City_AvgTime_grouped = Complaint_City_AvgTime_grouped.rename(columns={'hours':'complaint_resovled'})

Complaint_City_AvgTime_grouped = Complaint_City_AvgTime_grouped.sort_values(
    ['City','complaint_resovled'])

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
Complaint_City_AvgTime_grouped

Complaint_City_AvgTime_grouped.head(100)
# Out:
#                                         complaint_resovled
# City         Complaint Type
# ARVERNE      Drinking                             0.250000
#              Vending                              0.483333
#              Urinating in Public                  0.700000
#              Panhandling                          1.033333
#              Noise - Park                         1.283333
#              Graffiti                             1.533333
#              Noise - House of Worship             1.560606
#              Homeless Encampment                  1.816667
#              Noise - Vehicle                      1.861905
#              Noise - Street/Sidewalk              1.991379
#              Animal Abuse                         2.153947
#              Noise - Commercial                   2.291667
#              Illegal Parking                      2.316954
#              Blocked Driveway                     2.527143
#              Derelict Vehicle                     2.966049
#              Disorderly Youth                     3.591667
# ASTORIA      Panhandling                          1.150000
#              Bike/Roller/Skate Chronic            1.737778
#              Noise - House of Worship             2.023684
#              Illegal Fireworks                    2.775000
#              Disorderly Youth                     2.905556
#              Noise - Park                         2.995355
#              Noise - Commercial                   3.132882
#              Noise - Street/Sidewalk              3.450993
#              Noise - Vehicle                      3.508987
#              Urinating in Public                  4.625926
#              Drinking                             4.721905
#              Blocked Driveway                     4.815960
#              Illegal Parking                      4.833271
#              Homeless Encampment                  4.915625
#              Vending                              4.933642
#              Animal Abuse                         5.000133
#              Traffic                              5.408865
#              Posting Advertisement                5.883333
#              Derelict Vehicle                     9.689079
#              Graffiti                            14.100000
# Astoria      Noise - Commercial                   3.542209
#              Noise - Street/Sidewalk              3.714035
#              Illegal Parking                      4.711111
#              Blocked Driveway                     4.914655
#              Derelict Vehicle                     6.234722
# BAYSIDE      Traffic                              1.527778
#              Noise - Street/Sidewalk              1.531111
#              Noise - Vehicle                      1.707292
#              Vending                              1.883333
#              Drinking                             1.900000
#              Noise - Commercial                   2.234167
#              Illegal Parking                      2.562419
#              Blocked Driveway                     2.563086
#              Homeless Encampment                  2.875000
#              Disorderly Youth                     2.966667
#              Noise - Park                         3.270833
#              Animal Abuse                         3.274775
#              Derelict Vehicle                     3.359428
#              Noise - House of Worship             3.533333
#              Graffiti                             4.550000
# BELLEROSE    Noise - Park                         1.416667
#              Disorderly Youth                     1.850000
#              Noise - House of Worship             2.200000
#              Posting Advertisement                2.250000
#              Noise - Vehicle                      2.583333
#              Drinking                             3.916667
#              Bike/Roller/Skate Chronic            4.900000
#              Traffic                              5.759524
#              Illegal Fireworks                    6.666667
#              Noise - Commercial                   6.741441
#              Panhandling                          7.483333
#              Urinating in Public                  7.550000
#              Illegal Parking                      8.202830
#              Noise - Street/Sidewalk              9.067949
#              Blocked Driveway                    10.099825
#              Animal Abuse                        12.723810
#              Derelict Vehicle                    17.167603
#              Homeless Encampment                 39.133333
# BREEZY POINT Noise - Street/Sidewalk              1.000000
#              Noise - Vehicle                      1.316667
#              Blocked Driveway                     1.322222
#              Noise - Commercial                   2.537500
#              Animal Abuse                         2.608333
#              Drinking                             2.633333
#              Illegal Parking                      3.942222
#              Derelict Vehicle                     7.155556
# BRONX        Bike/Roller/Skate Chronic            3.459167
#              Posting Advertisement                3.464706
#              Disorderly Youth                     4.238889
#              Noise - House of Worship             4.558650
#              Noise - Commercial                   4.697349
#              Noise - Park                         4.698934
#              Traffic                              4.923850
#              Noise - Street/Sidewalk              5.226228
#              Urinating in Public                  5.389869
#              Noise - Vehicle                      5.560665
#              Illegal Fireworks                    5.609028
#              Drinking                             5.793351
#              Blocked Driveway                     6.261792
#              Illegal Parking                      6.580875
#              Vending                              6.826165
#              Animal Abuse                         7.335501
#              Homeless Encampment                  7.441430
#              Graffiti                             8.900000

# %% [markdown]
# 5. Perform a statistical test for the following:
# (For the below statements you need to state the Null and Alternate and then provide a statistical test to accept or reject the Null Hypothesis along with the corresponding ‘p-value’.)
#
# Whether the average response time across complaint types is similar or not (overall)
# Are the type of complaint or service requested and location related?

# %%
import scipy.stats as stat

# %%
Complaint_AvgTime = data_place_CType_RCTime.groupby(['Complaint Type']).agg({'hours':'mean'})
Complaint_AvgTime = pd.DataFrame(Complaint_AvgTime)
Complaint_AvgTime = Complaint_AvgTime.sort_values(['hours']).reset_index()
Complaint_AvgTime
# Out:
#                Complaint Type       hours
# 0       Posting Advertisement    1.975694
# 1           Illegal Fireworks    2.761806
# 2          Noise - Commercial    3.147195
# 3    Noise - House of Worship    3.193416
# 4                Noise - Park    3.410724
# 5     Noise - Street/Sidewalk    3.445181
# 6                     Traffic    3.448651
# 7            Disorderly Youth    3.558333
# 8             Noise - Vehicle    3.588981
# 9         Urinating in Public    3.626745
# 10  Bike/Roller/Skate Chronic    3.766234
# 11                   Drinking    3.861791
# 12                    Vending    4.014049
# 13                   Squeegee    4.045833
# 14        Homeless Encampment    4.365512
# 15                Panhandling    4.372186
# 16            Illegal Parking    4.501141
# 17           Blocked Driveway    4.740912
# 18               Animal Abuse    5.213219
# 19              Agency Issues    5.258333
# 20                   Graffiti    7.151327
# 21           Derelict Vehicle    7.364149
# 22           Animal in a Park  336.850000

# %%
Tmean_without = float(Complaint_AvgTime[Complaint_AvgTime['Complaint Type']!='Animal in a Park'].mean())
print("Without complaint type 'Animal in a Park' ----- ",Tmean_without)
Tmean_with = float(Complaint_AvgTime['hours'].mean())
print("With complaint type 'Animal in a Park' ----- ",Tmean_with)
# Out:
# Without complaint type 'Animal in a Park' -----  4.127791517561884
# With complaint type 'Animal in a Park' -----  18.593974495059193
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_7512\4040558461.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Tmean_without = float(Complaint_AvgTime[Complaint_AvgTime['Complaint Type']!='Animal in a Park'].mean())

# %% [markdown]
# With complaint type 'Animal in a Park'

# %%
ttest_with, pval_with = stat.ttest_1samp(Complaint_AvgTime['hours'], Tmean_with)
print('T-statistic is =',ttest_with)
print('p value is =',np.around(pval_with))
# Out:
# T-statistic is = 0.0
# p value is = 1.0

# %%
if (pval_with<0.05):
    print('Null hypothesis is rejected since p value ({}) is less than 0.05'.format(np.around(pval_with,decimals=2)))
else:
    print('Null hypothesis is accepted since p value ({}) is greater than 0.05'.format(np.around(pval_with,decimals=2)))
# Out:
# Null hypothesis is accepted since p value (1.0) is greater than 0.05

# %% [markdown]
# Without complaint type 'Animal in a Park'

# %%
Complaint_AvgTime_without = Complaint_AvgTime.drop([len(Complaint_AvgTime)-1],axis=0)
Complaint_AvgTime_without
# Out:
#                Complaint Type     hours
# 0       Posting Advertisement  1.975694
# 1           Illegal Fireworks  2.761806
# 2          Noise - Commercial  3.147195
# 3    Noise - House of Worship  3.193416
# 4                Noise - Park  3.410724
# 5     Noise - Street/Sidewalk  3.445181
# 6                     Traffic  3.448651
# 7            Disorderly Youth  3.558333
# 8             Noise - Vehicle  3.588981
# 9         Urinating in Public  3.626745
# 10  Bike/Roller/Skate Chronic  3.766234
# 11                   Drinking  3.861791
# 12                    Vending  4.014049
# 13                   Squeegee  4.045833
# 14        Homeless Encampment  4.365512
# 15                Panhandling  4.372186
# 16            Illegal Parking  4.501141
# 17           Blocked Driveway  4.740912
# 18               Animal Abuse  5.213219
# 19              Agency Issues  5.258333
# 20                   Graffiti  7.151327
# 21           Derelict Vehicle  7.364149

# %%
ttest_without, pval_without = stat.ttest_1samp(Complaint_AvgTime_without['hours'], Tmean_without)
print('T-statistic is =',ttest_without)
print('p value is =',np.around(pval_without,decimals=8))
# Out:
# T-statistic is = 0.0
# p value is = 1.0

# %%
if (pval_without<0.05):
    print('Null hypothesis is rejected since p value ({}) is less than 0.05'.format(np.around(pval_without,decimals=2)))
else:
    print('Null hypothesis is accepted since p value ({}) is greater than 0.05'.format(np.around(pval_without,decimals=2)))
# Out:
# Null hypothesis is accepted since p value (1.0) is greater than 0.05

# %% [markdown]
# (b) 2-sample T-test

# %%
sample1 = Complaint_AvgTime.sample(frac=.5)
sample1
# Out:
#                Complaint Type       hours
# 15                Panhandling    4.372186
# 4                Noise - Park    3.410724
# 12                    Vending    4.014049
# 13                   Squeegee    4.045833
# 16            Illegal Parking    4.501141
# 18               Animal Abuse    5.213219
# 19              Agency Issues    5.258333
# 9         Urinating in Public    3.626745
# 22           Animal in a Park  336.850000
# 20                   Graffiti    7.151327
# 10  Bike/Roller/Skate Chronic    3.766234
# 6                     Traffic    3.448651

# %%
sample2 = Complaint_AvgTime.drop(sample1.index)
sample2
# Out:
#               Complaint Type     hours
# 0      Posting Advertisement  1.975694
# 1          Illegal Fireworks  2.761806
# 2         Noise - Commercial  3.147195
# 3   Noise - House of Worship  3.193416
# 5    Noise - Street/Sidewalk  3.445181
# 7           Disorderly Youth  3.558333
# 8            Noise - Vehicle  3.588981
# 11                  Drinking  3.861791
# 14       Homeless Encampment  4.365512
# 17          Blocked Driveway  4.740912
# 21          Derelict Vehicle  7.364149

# %%
print('Mean of 1st sample =',np.around(float(sample1['hours'].mean()),decimals=2))
print('Standard dev. of 1st sample =',np.around(float(sample1['hours'].std()),decimals=2))
print('Mean of 2nd sample =',np.around(float(sample2['hours'].mean()),decimals=2))
print('Standard dev. of 2nd sample =',np.around(float(sample2['hours'].std()),decimals=2))
# Out:
# Mean of 1st sample = 32.14
# Standard dev. of 1st sample = 95.97
# Mean of 2nd sample = 3.82
# Standard dev. of 2nd sample = 1.39

# %%
ttest_2sp, p_val = stat.ttest_ind(sample1['hours'],sample2['hours'])
print('T-statistic is =',ttest_2sp)
print('p value is =',np.around(p_val,decimals=2))
# Out:
# T-statistic is = 0.976722426730914
# p value is = 0.34

# %%
if (p_val<0.05):
    print('Null hypothesis is rejected since p value ({}) is less than 0.05'.format(np.around(p_val,decimals=2)))
else:
    print('Null hypothesis is accepted since p value ({}) is greater than 0.05'.format(np.around(p_val,decimals=2)))
# Out:
# Null hypothesis is accepted since p value (0.34) is greater than 0.05

# %%
sample1_anova = Complaint_AvgTime.sample(frac=1/3)
sample1_anova
# Out:
#            Complaint Type     hours
# 13               Squeegee  4.045833
# 8         Noise - Vehicle  3.588981
# 7        Disorderly Youth  3.558333
# 0   Posting Advertisement  1.975694
# 14    Homeless Encampment  4.365512
# 17       Blocked Driveway  4.740912
# 2      Noise - Commercial  3.147195
# 19          Agency Issues  5.258333

# %%
rest_data = Complaint_AvgTime.drop(sample1_anova.index)
rest_data
# Out:
#                Complaint Type       hours
# 1           Illegal Fireworks    2.761806
# 3    Noise - House of Worship    3.193416
# 4                Noise - Park    3.410724
# 5     Noise - Street/Sidewalk    3.445181
# 6                     Traffic    3.448651
# 9         Urinating in Public    3.626745
# 10  Bike/Roller/Skate Chronic    3.766234
# 11                   Drinking    3.861791
# 12                    Vending    4.014049
# 15                Panhandling    4.372186
# 16            Illegal Parking    4.501141
# 18               Animal Abuse    5.213219
# 20                   Graffiti    7.151327
# 21           Derelict Vehicle    7.364149
# 22           Animal in a Park  336.850000

# %%
sample2_anova = rest_data.sample(frac=1/2)
sample2_anova
# Out:
#              Complaint Type       hours
# 4              Noise - Park    3.410724
# 22         Animal in a Park  336.850000
# 18             Animal Abuse    5.213219
# 9       Urinating in Public    3.626745
# 15              Panhandling    4.372186
# 1         Illegal Fireworks    2.761806
# 5   Noise - Street/Sidewalk    3.445181
# 6                   Traffic    3.448651

# %%
sample3_anova = rest_data.drop(sample2_anova.index)
sample3_anova
# Out:
#                Complaint Type     hours
# 3    Noise - House of Worship  3.193416
# 10  Bike/Roller/Skate Chronic  3.766234
# 11                   Drinking  3.861791
# 12                    Vending  4.014049
# 16            Illegal Parking  4.501141
# 20                   Graffiti  7.151327
# 21           Derelict Vehicle  7.364149

# %%
print('Mean of 1st sample =',np.around(float(sample1_anova['hours'].mean()),decimals=2))
print('Standard dev. of 1st sample =',np.around(float(sample1_anova['hours'].std()),decimals=2))
print('Mean of 2nd sample =',np.around(float(sample2_anova['hours'].mean()),decimals=2))
print('Standard dev. of 2nd sample =',np.around(float(sample2_anova['hours'].std()),decimals=2))
print('Mean of 3rd sample =',np.around(float(sample3_anova['hours'].mean()),decimals=2))
print('Standard dev. of 3rd sample =',np.around(float(sample3_anova['hours'].std()),decimals=2))
# Out:
# Mean of 1st sample = 3.84
# Standard dev. of 1st sample = 1.02
# Mean of 2nd sample = 45.39
# Standard dev. of 2nd sample = 117.77
# Mean of 3rd sample = 4.84
# Standard dev. of 3rd sample = 1.7

# %% [markdown]
# (a) Shapiro-Wilk normality test for each data group

# %%
f_val,p_val = stat.shapiro(sample1_anova['hours'])
print('F-statistic is =',f_val)
print('p value is =',np.around(p_val,decimals=2))
# Out:
# F-statistic is = 0.9754675626754761
# p value is = 0.94

# %%
f_val,p_val = stat.shapiro(sample2_anova['hours'])
print('F-statistic is =',f_val)
print('p value is =',np.around(p_val,decimals=2))
# Out:
# F-statistic is = 0.42397600412368774
# p value is = 0.0

# %%
f_val,p_val = stat.shapiro(sample3_anova['hours'])
print('F-statistic is =',f_val)
print('p value is =',np.around(p_val,decimals=2))
# Out:
# F-statistic is = 0.7962175607681274
# p value is = 0.04

# %% [markdown]
# All p values are greater than 0.05
# Fail to reject the null hypothesis
# Samples come from populations that follow normal distribution

# %% [markdown]
# (c) One way ANOVA

# %%
f_val,p_val = stat.f_oneway(sample1_anova['hours'],sample2_anova['hours'],sample3_anova['hours'])
print('F-statistic is =',f_val)
print('p value is =',np.around(p_val,decimals=2))
# Out:
# F-statistic is = 0.907428683830073
# p value is = 0.42

# %%
if (p_val<0.05):
    print('Null hypothesis is rejected since p value ({}) is less than 0.05'.format(np.around(p_val,decimals=2)))
else:
    print('Null hypothesis is accepted since p value ({}) is greater than 0.05'.format(np.around(p_val,decimals=2)))
# Out:
# Null hypothesis is accepted since p value (0.42) is greater than 0.05

# %% [markdown]
# All the cases p-value is greater than 0.05
# Fail to reject the null hypothesis.
# All the tests (T-test, F-test) provide a common conclusion. That is we fail to reject the 'Null hypothesis'.
#
# Null Hypothesis states - there is no significant relationship among the average response time across complaint types
#
# Alternate Hypothesis states - there is a significant relationship among the average response time across complaint types
#
# Thus we may conclude that there is no significant relationship among the average response time across complaint types or they are not similar types.
